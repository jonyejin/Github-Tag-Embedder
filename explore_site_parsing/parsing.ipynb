# %% [markdown]
# # Unsupervised image denoising

# %% [markdown]
# ## Import libraries

# %%
import torch
import torchvision
from torch.utils.data import Dataset
from os import listdir
from os.path import join
from torchvision.transforms import Compose, ToTensor, ToPILImage, Resize, Lambda, Normalize, Grayscale
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from math import log10
from tqdm.notebook import tqdm
import os
import pandas as pd

# %% [markdown]
# ## Load data

# %%
directory_data  = '/Users/songchihyun/Desktop/2022-2학기/빅데이터/빅데이터/explore-main/_topics'
file_names = os.listdir(directory_data)
filename_data   = 'index.md'
# data            = np.load(os.path.join(directory_data, filename_data))
dataFrame = pd.DataFrame()
print(len(file_names))
dict_full = {}
for file_name in file_names:
  if(file_name == '.DS_Store' or file_name == 'index.md'):
    break
  directory_name = directory_data + '/' + file_name + '/'
  data = open(os.path.join(directory_name, filename_data),'r')
  chunk = data.read().strip()
  lines = chunk.split('\n')
  
  lines2 = chunk.split('---')

  # print(chunk)
  # print(len(lines2))
  df = pd.DataFrame(lines)
  # print(df)
  dict = {}
  for line in lines:
    
    split = line.split(":")
    
    if len(split) == 2:
      dict[split[0]] = split[1]
    
    # list = value.to_string().pslit(':')
  description = lines2[len(lines2)-1]
  dict['description'] = description.strip()
  dict_full[file_name] = dict    
#     if list.count == 2:
#       print(list[0])
#       print(list[1])
#       dict[list[0]] = list[1]
# print(dict_full)
import json
with open('output.json','w') as fp:
  json.dump(dict_full,fp)

dict_concat = {}
for key,dict in dict_full.items():
  line = ""
  for value in dict.values():
    line = line + value + " "
  dict_concat[key] = line.strip()
# with open('concat_output.json','w') as fp:
#   json.dump(dict_concat,fp)
  # list = value.str.split(':')
  # print(list)
# Out:
# 788

# %%
import json
with open('concat_output.json', 'r') as file:
    data = json.load(file)
for key,line in data.items():
  arr = line.split(' ')
  remove = {''}
  arr = [i for i in arr if i not in remove]
  data[key] = arr
print(data)
# Out:
# {'svg': ['svg', 'SVG', 'svg.png', 'September', '4,', '2001', 'SVG', 'is', 'an', 'XML-based', 'markup', 'language', 'for', 'describing', 'two-dimensional', 'based', 'vector', 'graphics.', 'xml', 'Scalable', 'Vector', 'Graphics', '(SVG)', 'is', 'an', 'XML-based', 'vector', 'image', 'format', 'for', 'defining', 'two-dimensional', 'graphics,', 'having', 'support', 'for', 'interactivity', 'and', 'animation.', 'The', 'SVG', 'specification', 'is', 'an', 'open', 'standard', 'developed', 'by', 'the', 'World', 'Wide', 'Web', 'Consortium', '(W3C)', 'since', '1999.'], 'apple': ['Steve', 'Jobs,', 'Steve', 'Wozniak,', 'Ronald', 'Wayne', 'Apple', 'apple.png', 'swift,', 'macos,', 'ios', 'Apple', 'is', 'a', 'prominent', 'hardware', 'and', 'software', 'company.', 'April', '1,', '1976', 'apple', 'Apple', 'Inc.', 'designs,', 'manufactures', 'and', 'markets', 'smartphones,', 'personal', 'computers,', 'tablets,', 'wearables', 'and', 'accessories,', 'and', 'sells', 'a', 'variety', 'of', 'related', 'services.', 'The', "company's", 'products', 'include', 'iPhone,', 'Mac,', 'iPad,', 'and', 'Wearables,', 'Home', 'and', 'Accessories.'], 'b4x': ['b4x', 'B4X', 'b4x-programming-language', 'b4a,', 'b4i,', 'b4j,', 'b4r', 'B4X', 'is', 'a', 'rapid', 'application', 'development', 'tool', 'and', 'new', 'programming', 'language', 'to', 'create', 'cross', 'platform', 'apps.', 'Anywhere', 'Software', '|', 'Erel', 'Uziel', 'B4X', 'is', 'a', 'suite', 'of', 'rapid', 'application', 'development', 'IDEs', 'and', 'proprietary', 'programming', 'language', 'that', 'allows', 'the', 'creation', 'of', 'applications', 'on', 'the', 'following', 'platforms-', 'Google', 'Android,', 'Apple', 'iOS,', 'Java,', 'Raspberry', 'Pi,', 'and', 'Arduino.', 'Although', 'the', 'B4X', 'syntax', 'is', 'very', 'similar', 'to', 'BASIC,', 'it', 'is', 'an', 'entirely', 'new', 'language.'], 'frame-interpolation': ['video-interpolation,', 'image-interpolation', 'Frame', 'Interpolation', 'video,', 'machine-learning,', 'ai', 'Methods', 'for', 'compositing', 'new', 'images', 'between', 'two', 'filmed', 'or', 'photographed', 'images.', 'frame-interpolation', 'Frame', 'interpolation', 'is', 'used', 'to', 'increase', 'the', 'frame', 'rate', 'of', 'a', 'video,', 'or', 'to', 'create', 'a', 'slow-motion', 'video', 'without', 'lowering', 'the', 'frame', 'rate.'], 'ocaml': ['Xavier', 'Leroy', 'OCaml', 'ocaml.png', '1996', 'OCaml', 'is', 'an', 'implementation', 'of', 'the', 'ML', 'language,', 'based', 'on', 'the', 'Caml', 'Light.', 'ocaml', 'OCaml', 'is', 'a', 'general', 'purpose', 'industrial-strength', 'programming', 'language', 'with', 'an', 'emphasis', 'on', 'expressiveness', 'and', 'safety,', 'It', 'is', 'supporting', 'functional,', 'imperative', 'and', 'object-oriented', 'styles.'], 'wsl': ['windows-subsystem-linux', 'Windows', 'Subsystem', 'for', 'Linux', 'Run', 'Linux', 'apps', 'natively', 'on', 'Windows.', 'wsl', 'The', 'Windows', 'Subsystem', 'for', 'Linux', 'lets', 'developers', 'run', 'a', 'GNU/Linux', 'environment', '--', 'including', 'most', 'command-line', 'tools,', 'utilities,', 'and', 'applications', '--', 'directly', 'on', 'Windows,', 'unmodified,', 'without', 'the', 'overhead', 'of', 'a', 'traditional', 'virtual', 'machine,', 'or', 'dualboot', 'setup.You', 'can', '-', 'Choose', 'your', 'favorite', 'GNU/Linux', 'distributions', 'from', 'the', 'Microsoft', 'Store.', 'Run', 'common', 'command-line', 'tools', 'such', 'as', 'grep,', 'sed,', 'awk,', 'or', 'other', 'ELF-64', 'binaries.', 'Run', 'Bash', 'shell', 'scripts', 'and', 'GNU/Linux', 'command-line', 'applications', 'including', '-', 'Tools', '-', 'vim,', 'emacs,', 'tmux', 'Languages', '-', 'NodeJS,', 'Javascript,', 'Python,', 'Ruby,', 'C/C++,', 'C#', '&', 'F#,', 'Rust,', 'Go,', 'etc.', 'Services', '-', 'SSHD,', 'MySQL,', 'Apache,', 'lighttpd,', 'MongoDB,', 'PostgreSQL.', 'Install', 'additional', 'software', 'using', 'your', 'own', 'GNU/Linux', 'distribution', 'package', 'manager.', 'Invoke', 'Windows', 'applications', 'using', 'a', 'Unix-like' ...

# %%
directory_data  = '/Users/songchihyun/Desktop/2022-2학기/빅데이터/빅데이터/'
file_names = os.listdir(directory_data)
filename_data   = 'output.csv'
csv = pd.read_csv(os.path.join(directory_data,filename_data))
print(csv)
# Out:
#           Unnamed: 0                                                svg  \
# 0              topic                                                svg
# 1       display_name                                                SVG
# 2               logo                                            svg.png
# 3           released                                  September 4, 2001
# 4  short_description   SVG is an XML-based markup language for descr...
# 5            related                                                xml
# 6        description  Scalable Vector Graphics (SVG) is an XML-based...
# 7         created_by                                                NaN
# 8            aliases                                                NaN
#
#                                                apple  \
# 0                                              apple
# 1                                              Apple
# 2                                          apple.png
# 3                                      April 1, 1976
# 4   Apple is a prominent hardware and software co...
# 5                                  swift, macos, ios
# 6  Apple Inc. designs, manufactures and markets s...
# 7            Steve Jobs, Steve Wozniak, Ronald Wayne
# 8                                                NaN
#
#                                                  b4x  \
# 0                                                b4x
# 1                                                B4X
# 2                                                NaN
# 3                                                NaN
# 4   B4X is a rapid application development tool a...
# 5                                 b4a, b4i, b4j, b4r
# 6  B4X is a suite of rapid application developmen...
# 7                     Anywhere Software | Erel Uziel
# 8                           b4x-programming-language
#
#                                  frame-interpolation  \
# 0                                frame-interpolation
# 1                                Frame Interpolation
# 2                                                NaN
# 3                                                NaN
# 4   Methods for compositing new images between tw...
# 5                        video, machine-learning, ai
# 6  Frame interpolation is used to increase the fr...
# 7                                                NaN
# 8           video-interpolation, image-interpolation
#
#                                                ocaml  \
# 0                                              ocaml
# 1                                              OCaml
# 2                                          ocaml.png
# 3                                               1996
# 4   OCaml is an implementation of the ML language...
# 5                                                NaN
# 6  OCaml is a general purpose industrial-strength...
# 7                                       Xavier Leroy
# 8                                                NaN
#
#                                                  wsl  \
# 0                                                wsl
# 1                        Windows Subsystem for Linux
# 2                                                NaN
# 3                                                NaN
# 4                Run Linux apps natively on Windows.
# 5                                                NaN
# 6  The Windows Subsystem for Linux lets developer...
# 7                                                NaN
# 8                            windows-subsystem-linux
#
#                                              firefox  \
# 0                                            firefox
# 1                                            Firefox
# 2                                        firefox.png
# 3                                 September 23, 2002
# 4   Firefox is an open source web browser from Mo...
# 5   mozilla,chrome,safari,edge,opera,browser,geck...
# 6  Firefox is a free and open source web browser ...
# 7                                            Mozilla
# 8    mozilla-firefox,firefox-quantum,firefox-browser
#
#                                                  jwt  \
# 0                                                jwt
# 1                                    JSON Web Tokens
# 2                                                NaN
# 3                                           May 2015
# 4   JSON Web Tokens are an open, industry standar...
# 5              json, jwt-token, jwt-tokens, jwt-auth
# 6  JSON Web Token (JWT) is a compact, URL-safe me...
# 7                  M. Jones, J. Bradley, N. Sakimura
# 8                                           rfc-7519
#
#                                           backbonejs  ...  \
# 0                                         backbonejs  ...
# 1                                        Backbone.js  ...
# 2                                     backbonejs.png  ...
# 3                                   October 13, 2010  ...
# 4   Backbone.js is a JavaScript library for build...  ...
# 5                                                NaN  ...
# 6  Backbone supplies structure to JavaScript-heav...  ...
# 7                                    Jeremy Ashkenas  ...
# 8                                           backbone  ...
#
#                                           obofoundry  \
# 0                                         obofoundry
# 1                                        OBO Foundry
# 2                                     obofoundry.png
# 3                                               2003
# 4   The OBO Foundry is a community and infrastruc...
# 5           web-ontology-language, owl, owl-ontology
# 6  The mission of the OBO Foundry is to develop a...
# 7                                                NaN
# 8                                                obo
#
#                                                macos  \
# 0                                              macos
# 1                                              macOS
# 2                                          macos.png
# 3                                     March 24, 2001
# 4                 macOS is Apple's operating system.
# 5                                                NaN
# 6  macOS is the operating system that powers ever...
# 7                                              Apple
# 8      macosx, macos-sierra, macos-app, mac-osx, mac
#
#                                          obsidian-md  \
# 0                                        obsidian-md
# 1                                           Obsidian
# 2                                    obsidian-md.png
# 3                                           May 2020
# 4   Obsidian is a note taking app that edits loca...
# 5                                                NaN
# 6  Obsidian is a powerful knowledge base that wor...
# 7                              Shida Li and Erica Xu
# 8                                           obsidian
#
#                                            streamlit  \
# 0                                          streamlit
# 1                                          Streamlit
# 2                                      streamlit.png
# 3                                     March 27, 2018
# 4   Streamlit is an open source Python library th...
# 5                                                NaN
# 6  Streamlit is an open source Python library tha...
# 7     Adrien Treuille, Amanda Kelly, Thiago Teixeira
# 8                                                NaN
#
#                                       robotframework  \
# 0                                     robotframework
# 1                                    Robot Framework
# 2                                 robotframework.png
# 3                                            06 2008
# 4   Robot Framework is an easy to learn and to ea...
# 5   automation, testautomation, rpa, atdd, bdd, c...
# 6  **Robot Framework** is an open source, easy to...
# 7                                       Pekka Klärck
# 8                     robot-framework, rf, rbtfrmwrk
#
#                                              discord  \
# 0                                            discord
# 1                                            Discord
# 2                                        discord.png
# 3                                                NaN
# 4   Discord is a free voice, video, and text chat...
# 5                                                NaN
# 6  Discord is a proprietary freeware voice-over-I...
# 7                                                NaN
# 8                                         discordapp
#
#                                                steam  \
# 0                                              steam
# 1                                             Steam
# 2                                          steam.png
# 3                                 September 12, 2003
# 4   Steam is a video game digital distribution se...
# 5                            steam-api, steam-client
# 6  Steam is a video game digital distribution ser...
# 7                                  Valve Corporation
# 8                                                NaN
#
#                                             effector  \
# 0                                           effector
# 1                                           Effector
# 2                                       effector.png
# 3                                          June 2019
# 4   Effector is an effective multi-store state ma...
# 5                      react, javascript, typescript
# 6  Effector allows you to manage data in complex ...
# 7                                           ZeroBias
# 8                            effectorjs, effector-js
#
#                                finite-element-method  \
# 0                              finite-element-method
# 1                        Finite Element Method (FEM)
# 2                          finite-element-method.png
# 3                                                NaN
# 4   The finite element method (FEM) is a numerica...
# 5                                                NaN
# 6  The finite element method (FEM) is a numerical...
# 7                                                NaN
# 8   fem, fea, finite-element-analysis, finite-ele...
#
#                                                   go
# 0                                                 go
# 1                                                 Go
# 2                                             go.png
# 3                                  November 10, 2009
# 4   Go is a programming language built to resembl...
# 5                                        language, c
# 6  Go is a programming language built to resemble...
# 7           Robert Griesemer, Rob Pike, Ken Thompson
# 8                            golang, golang-examples
#
# [9 rows x 117 columns]
